# %%
a = 19.6

type(a)
# Out:
# float

# %%
print("This is SyntaxError')
print(hello)
# Out:
#   Cell In[6], line 1
#     print("This is SyntaxError')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
name = input()
print("Chatbot: Xin chào " + name + "!")
# Out:
# Vân
# Chatbot: Xin chào Vân!

# %%
name = input()
age = input()
location = input()

print("Bạn là: {name} {age} tuổi ở {location}")
# Out:
# 12
# 14
# XTD
# Bạn là: {name} {age} tuổi ở {location}

# %%
name = input()
age = input()
location = input()

print("Bạn là: " + name + " " + age + " tuổi ở " +location)
# Out:
# Vân
# 20
# XTD
# Bạn là: Vân 20 tuổi ở XTD

# %%
a = 100
print(type(a))
print(type(100.30))
b = 10 + 24j
print(b + 20)
print(isinstance(b, complex))
# Out:
# <class 'int'>
# <class 'float'>
# (30+24j)
# True

# %%
a=input("a= ")
b=input("b= ")
print("a+b=", a+b)
# Out:
# a= 2
# b= 5
# a+b= 25

# %%
a=input("a= ")
# Out:
# a= 2

# %%
a = (float)15
b = 8.5

print(a + "nhân" + b + "cho kết quả là:" + a*b)
# Out:
#   Cell In[10], line 1
#     a = (float)15
#                ^
# SyntaxError: invalid syntax

# %%
a = 15
b = 88

print(a + "nhân" + b + "cho kết quả là:" + a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 a = 15
#       2 b = 88
# ----> 4 print(a + "nhân" + b + "cho kết quả là:" + a*b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 15
b = 8.5

print(a + "nhân" + b + "cho kết quả là:", a*b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 a = 15
#       2 b = 8.5
# ----> 4 print(a + "nhân" + b + "cho kết quả là:", a*b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 15
b = 8.5

print(a, "nhân", b, "cho kết quả là:", a*b)
# Out:
# 15 nhân 8.5 cho kết quả là: 127.5

# %%
a=50
b=200
"""In ra giá trị của
a và b"""
print(a)
print(b)
'In ra tích của a*b'
print(a*b)
'In ra tổng của a và b'
tong=a+b
print("Tổng của a và b là: " + tong)
# Out:
# 50
# 200
# 10000
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 11
#       9 'In ra tổng của a và b'
#      10 tong=a+b
# ---> 11 print("Tổng của a và b là: " + tong)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a=50
b=200
"""In ra giá trị của
a và b"""
print(a)
print(b)
'In ra tích của a*b'
print(a*b)
'In ra tổng của a và b'
tong=a+b
print("Tổng của a và b là:",tong)
# Out:
# 50
# 200
# 10000
# Tổng của a và b là: 250

# %%
a = 20 + 30j
print (type(a))
print (isinstance(a, complex))
# Out:
# <class 'complex'>
# True

# %%
c = int(input("Nhập c = "))
# Out:
# Nhập c = 12
