# %% [markdown]
# # DEFINE FUNCTION - EXAMPLE

# %%
def greater_than_million (value):
    if value > 1000000:
        return value * 0.0001
    else:
        return value *0.0003

# %%
greater_than_million(1090000)
# Out:
# 109.0

# %%
greater_than_million(20)
# Out:
# 0.005999999999999999
