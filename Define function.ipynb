# %% [markdown]
# # DEFINE FUNCTION

# %%
#def function_name(parameters):
    #function_body
    #return

# %%
def add_five(x):
    x = x+5
    print("Result")
    return x

# %%
add_five(7)
# Out:
# Result
# 12

# %%
add_five(5*12)
# Out:
# 65

# %%
def tong(x,y,z,t):
    ketqua=x+y+z+t
    return ketqua

# %%
tong(2,3,4,5)
# Out:
# 14

# %%
def cong_muoi(a):
    ket_qua1=a+10
    return ket_qua1

# %%
def nhan_hai(a):
    ket_qua2=cong_muoi(a)*2
    return ket_qua2

# %%
cong_muoi(5)
# Out:
# 15

# %%
nhan_hai(35)
# Out:
# 90

# %%
cong_muoi(34),nhan_hai(20)
# Out:
# (44, 60)
