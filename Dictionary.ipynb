# %% [markdown]
# # DICTIONARY

# %%
x={"key":"VNM","key1":"HPG","key2":"FPT"}

# %%
type(x)
# Out:
# dict

# %%
 x["key1"]
# Out:
# 'HPG'

# %%
x['key']
# Out:
# 'VNM'

# %%
x["key3"]="VNPT"

# %%
x
# Out:
# {'key': 'VNM', 'key1': 'HPG', 'key2': 'FPT', 'key3': 'VNPT'}

# %%
x["key3"]="REE"

# %%
x
# Out:
# {'key': 'VNM', 'key1': 'HPG', 'key2': 'FPT', 'key3': 'REE'}

# %%
dict={"Country":"US","EU_Region":["UK","Germany","Spain"]}

# %%
dict
# Out:
# {'Country': 'US', 'EU_Region': ['UK', 'Germany', 'Spain']}

# %%
dict["EU_Region"]
# Out:
# ['UK', 'Germany', 'Spain']

# %%
dict2={"key1":10,"key2":20,"key3":30}

# %%
dict2
# Out:
# {'key1': 10, 'key2': 20, 'key3': 30}

# %%
dict2["key2"]
# Out:
# 20
