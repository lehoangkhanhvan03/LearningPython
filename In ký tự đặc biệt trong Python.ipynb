# %%
a = ""Ready to go""
print(a)
# Out:
#   Cell In[1], line 1
#     a = ""Ready to go""
#           ^
# SyntaxError: invalid syntax

# %%
a = "\"Ready to go\""
print(a)
# Out:
# "Ready to go"

# %%
print("D:\\folder1\\folder2")
print("Javascript\rProgramming")
print("Python\vProgramming")
# Out:
# D:\folder1\folder2
# Programming
# PythonProgramming

# %%
print(r"Python\vProgramming")
# Out:
# Python\vProgramming
