# %% [markdown]
# # Indexing

# %%
x = ['a','b','c','d','e']

# %%
x[1]
# Out:
# 'b'

# %%
a = "Tui tên Vân" [6]

# %%
print(a)
# Out:
# n

# %% [markdown]
# # Indentation

# %%
gia_co_phieu = 20000

# %%
if gia_co_phieu > 12000:
    print("Mua")
else:
    print("Không mua")
# Out:
# Mua
