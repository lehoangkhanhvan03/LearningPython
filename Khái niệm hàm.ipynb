# %%
def vi_du(a):
   print("Lập trình "+a)
vi_du("Java")
# Out:
# Lập trình Java

# %%
def phep_chia(a, b):
    return a/b;
c = 400
d = 200
print("Kết quả phép chia là:",phep_chia(c,d))
# Out:
# Kết quả phép chia là: 2.0

# %%
def vi_du(a):
    print("Lập trình",a)
vi_du("Python")
# Out:
# Lập trình Python

# %%
def vi_du(a):
    return a
print(vi_du(400))
print(vi_du(4))
# Out:
# 400
# 4

# %%
def vi_du(a):
    """đây là dòng docstring"""
    print("In ra:",a)
vi_du("docstring")
print(vi_du.__doc__)
# Out:
# In ra: docstring
# đây là dòng docstring
