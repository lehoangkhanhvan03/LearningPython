# %% [markdown]
# # MODULE AND PACKAGE

# %% [markdown]
# # MODULE

# %%
import math

# %%
math.pow(5,2)
# Out:
# 25.0

# %%
math.pow(5,3)
# Out:
# 125.0

# %%
math.sqrt(81)
# Out:
# 9.0

# %%
import statsmodels

# %%
import tao_model

# %%
tao_model.tao_model
# Out:
# 'Tui ten Van'

# %% [markdown]
# # PACKAGE

# %%
# có thể bao gồm các Module

# %%
# Numpy: array

# %%
# Pandas: DataFrame (timeseries: dữ liệu theo thời gian)

# %%
# Matplotlib: Data Visualization

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import pandas_datareader as web
