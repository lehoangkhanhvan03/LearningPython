# %% [markdown]
# # Pandas - Series

# %%
import pandas as pd

# %%
list = [1,2,3,4,5]

# %%
pd.Series(list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
list2 = [5,8,1,2,10,54,34]

# %%
pd.Series(list2)
# Out:
# 0     5
# 1     8
# 2     1
# 3     2
# 4    10
# 5    54
# 6    34
# dtype: int64

# %%
new_list=[51,60,61,62,72]

# %%
labels=["HCM","DN","BD","LA","VT"]

# %%
series1=pd.Series(new_list,labels)

# %%
series1
# Out:
# HCM    51
# DN     60
# BD     61
# LA     62
# VT     72
# dtype: int64

# %%
import numpy as np

# %%
array1=np.array([51,60,61,62,72])

# %%
series2=pd.Series(array1,labels)

# %%
series2
# Out:
# HCM    51
# DN     60
# BD     61
# LA     62
# VT     72
# dtype: int32
