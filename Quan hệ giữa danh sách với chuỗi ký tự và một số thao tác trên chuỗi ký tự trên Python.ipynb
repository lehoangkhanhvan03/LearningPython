# %%
a = 'Python TEK4.VN!'
print(a)
print(a[2]) # Lấy ký tự thứ 3
# Out:
# Python TEK4.VN!
# t

# %%
a = 'Python'
print(a[-11]) # Lấy ký tự vị trí -11
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = 'Python'
# ----> 2 print(a[-11])
#
# IndexError: string index out of range

# %%
my_string = "Python is easy"
print(my_string[2:12:2]) 
print(my_string[2:12:3])
# Out:
# to se
# tnsa

# %%
my_string = "Python is easy"
print(my_string[::2])
# Out:
# Pto ses

# %%
my_string = "Python is easy"
print(my_string[::-1])
print(my_string[::-2])
# Out:
# ysae si nohtyP
# ya inhy

# %%
my_string = "Python is easy"
print(len(my_string))
# Out:
# 14

# %%
print(len("Let's print the length of this string."))
# Out:
# 38

# %%
my_string = "Python is easy"
print('P' in my_string)
print('Q' in my_string)
print ("Python" in my_string)
print ("TEK4.VN" not in my_string)
# Out:
# True
# False
# True
# True

# %%
a = 'Python'
print(a)
a[0] = 'A' #Lỗi
print(a)
a = 'Javascript'
print(a)
# Out:
# Python
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 a = 'Python'
#       2 print(a)
# ----> 3 a[0] = 'A' #Lỗi
#       4 print(a)
#       5 a = 'Javascript'
#
# TypeError: 'str' object does not support item assignment

# %%
s="Học Python với tek4.vn"
s_new = s[:4] + 'Java' + s[10:]
print(s_new)
# Out:
# Học Java với tek4.vn

# %%
a = 'Python'
print(a)
del a
# Out:
# Python

# %%
s1="Python"
s2="Python"
s3="Java"
s4="12345"
s5="12346"

print(s1==s2)
print(s4<s5)
print(s3>s1)
# Out:
# True
# True
# False

# %%
l1=[1,2,3,4]
l2=[1,2,3,4]
l3=[1,2,3,5]
print(l1==l2)
print(l3>l1)
# Out:
# True
# True

# %%
s=input()
if s == s[::-1]:
  print("Chuỗi vừa nhập là chuỗi Palindrome!")
else:
  print("Chuỗi vừa nhập KHÔNG phải là một chuỗi Palindrome!")
# Out:
# uuhuu
# Chuỗi vừa nhập là chuỗi Palindrome!

# %%
s=input()
if "Python" in s:
  print( s.replace("Python","Java"))
else:
  print ('Python does not exist in the string!')
# Out:
# Python is good
# Java is good
