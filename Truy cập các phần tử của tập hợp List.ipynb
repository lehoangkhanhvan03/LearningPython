# %%
my_list1 = list((1, 2, 3))
print(my_list1)
my_list2 = [1, 2, 3]
print(my_list2)

my_list3 = [300, "Python", 500.5]
print(my_list3)

my_list4 = list()
print(my_list4)
vi_du = []
print(vi_du)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [300, 'Python', 500.5]
# []
# []

# %%
vi_du1 = []
print (vi_du1)
vi_du2 = [100, 100.5, 200]
print (vi_du2)
vi_du3 = [300, "Python", [500.5, 200, "Javascript"]]
print(vi_du3)
# Out:
# []
# [100, 100.5, 200]
# [300, 'Python', [500.5, 200, 'Javascript']]

# %%
a = [1,2.3,'Vân',[10,12.4,"Lê"]]
print(a)
print(len(a))
# Out:
# [1, 2.3, 'Vân', [10, 12.4, 'Lê']]
# 4

# %%
a = [1 + 2, "a" * 5, 3]
print(a)
# Out:
# [3, 'aaaaa', 3]

# %%
a=56.8 
b=32.4
c = [1.2,5.8,a,b]
print(c)
luythua = [a, a**2, a**3, a**4]
print(luythua)
result=[a+b,a-b,a*b,a/b]
print(result)
# Out:
# [1.2, 5.8, 56.8, 32.4]
# [56.8, 3226.24, 183250.43199999997, 10408624.537599998]
# [89.19999999999999, 24.4, 1840.32, 1.7530864197530864]

# %%
vi_du = [100, 300, "Python", "Javascript"]
print(vi_du[0])
print(vi_du[3])
vi_du2 = ["Python", [100, 200, 300, 400]]
print(vi_du2[0])
print(vi_du2[1][2])
# Out:
# 100
# Javascript
# Python
# 300

# %%
vi_du2 = ["Python", [100, 200, 300, 400]]
print(vi_du2[-1])
print(vi_du2[-2])
# Out:
# [100, 200, 300, 400]
# Python

# %%
my_list=[-1.2, 18.9, 23, 12.4, 17.6, 23.5, 12.2,20.6, 11.5, 45.6]

i = int(input())

if i >= 0 and i <= len(my_list) - 1:
  print("Phần tử thứ", i, "từ cuối lên của danh sách có giá trị là", str(my_list[-i]) + ".")
elif i >= -len(my_list) and i <= -1:
  print("Phần tử thứ", i, "từ cuối lên của danh sách có giá trị là", str(my_list[-i - 1]) + ".")
else:
  print(i, "list index out of range")
# Out:
# 100
# 100 list index out of range

# %%
sinh_vien=["Hường","Phương Anh", "Hồng Nga", "Long", "Hiếu","Khôi"]
diem_toan=[9,8,7,8,9,9]
diem_ly=[10,8,9,9,8,10]
diem_hoa=[9,10,8,9,9,9]
print(sinh_vien[2])
print(diem_hoa[-1])
print('Sinh viên',sinh_vien[0],'có điểm trung bình là:',((diem_toan[0]+diem_ly[0]+diem_hoa[0])/3) + '.')
# Out:
# Hồng Nga
# 9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 print(sinh_vien[2])
#       6 print(diem_hoa[-1])
# ----> 7 print('Sinh viên',sinh_vien[0],'có điểm trung bình là:',((diem_toan[0]+diem_ly[0]+diem_hoa[0])/3) + '.')
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
sinh_vien=["Hường","Phương Anh", "Hồng Nga", "Long", "Hiếu","Khôi"]
del sinh_vien[]
# Out:
#   Cell In[13], line 2
#     del sinh_vien[]
#                   ^
# SyntaxError: invalid syntax
