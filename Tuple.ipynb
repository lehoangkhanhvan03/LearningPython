# %% [markdown]
# # TUPLE

# %%
x = (1,2,3,4,5)

# %%
x
# Out:
# (1, 2, 3, 4, 5)

# %%
x[0]
# Out:
# 1

# %%
type(x)
# Out:
# tuple

# %%
x,y,z=5,6,7

# %%
x
# Out:
# 5

# %%
y
# Out:
# 6

# %%
z
# Out:
# 7

# %%
x2=(5,6,7)

# %%
x3=(8,9,10)

# %%
list=[x2,x3]

# %%
list
# Out:
# [(5, 6, 7), (8, 9, 10)]

# %%
type(list)
# Out:
# list

# %%
 x,y,z=4,6,7

# %%
x
# Out:
# 4

# %%
z
# Out:
# 7
