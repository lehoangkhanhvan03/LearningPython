# %%
password = 45
if password == 43:
   print("Mật khẩu đúng")
print("Mời bạn nhập lại mật khẩu.")
# Out:
# Mời bạn nhập lại mật khẩu.

# %%
password = 43
if password == 43:
   print("Mật khẩu đúng")
print("Mời bạn nhập lại mật khẩu.")
# Out:
# Mật khẩu đúng
# Mời bạn nhập lại mật khẩu.

# %%
password = 45
if password == 43:
   print("Mật khẩu đúng")
else:
   print("Mật khẩu sai")
   print("Mời bạn nhập lại mật khẩu.")
# Out:
# Mật khẩu sai
# Mời bạn nhập lại mật khẩu.

# %%
ID_sv = 45
if ID_sv == 43:
   print("Là sinh viên trường Y")
elif ID_sv == 44:
   print("Là sinh viên trường Luật")
else:
   print("Là sinh viên trường Kỹ thuật")
# Out:
# Là sinh viên trường Kỹ thuật

# %%
ID_sv = 43
year = 3
if ID_sv == 43:
   print("Là sinh viên trường Y")
   if year == 3:
      print("Là sinh viên năm 3")
elif ID_sv == 44:
   print("Là sinh viên trường Luật")
   if year == 4:
      print("Là sinh viên năm cuối")
else:
   print("Là sinh viên trường Kỹ thuật")
# Out:
# Là sinh viên trường Y
# Là sinh viên năm 3

# %%
ID_sv = 43
year = 3
if ID_sv == 43:
   print("Là sinh viên trường Y")
   if year == 3:
      print("Là sinh viên năm 3")
elif ID_sv == 44:
   print("Là sinh viên trường Luật")
   if year == 4:
      print("Là sinh viên năm cuối")
else:
   print("Là sinh viên trường Kỹ thuật")
# Out:
# Là sinh viên trường Y
# Là sinh viên năm 3

# %%
a = int(input())
if a % 2 == 0:
  print ("Số",a,"là số chẵn !")
else:
  print ("Số",a,"là số lẻ !")
# Out:
# 19
# Số 19 là số lẻ !

# %%
num1 = int(input())
num2 = int(input())

if num1 >= num2:
    if num1 == num2:
      print(num1, 'và', num2, 'bằng nhau')
      print("Tích của",num1,"và",num2,"là:",num1*num2)  
    else:
      print(num1, 'lớn hơn', num2)
      print("Hiệu của", num1,"và",num2,"là:",num1-num2)
else:
      print(num1, 'is smaller than', num2)
      print("Tổng của",num1,"và",num2,"là:",num1+num2)
# Out:
# 13
# 17
# 13 is smaller than 17
# Tổng của 13 và 17 là: 30

# %%
year=int(input("Nhập năm: "))

if year%4==0:
    if year%100==0 and year%400!=00:
        print("Năm", year, "không phải là năm nhuận!")
    else:
        print("Năm", year, "là năm nhuận!")
else:
    print("Năm", year, "không phải là năm nhuận!")
# Out:
# Nhập năm: 1204
# Năm 1204 là năm nhuận!
